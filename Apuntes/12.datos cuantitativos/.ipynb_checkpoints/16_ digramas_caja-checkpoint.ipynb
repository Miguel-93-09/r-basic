# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(19880519)

# %%
dist1 = 100 * np.random.rand(50)
dist2 = 50 * np.ones(25)
dist3 = 100 + 100*np.random.rand(10)
dist4 = -100 * np.random.rand(10)

data = np.concatenate((dist1,dist2,dist3,dist4))

# %%
#alternativa a concatenate no funciona porque todos son distintos
#data_2 = np.array([dist1,dist2,dist3,dist4])

# %%
data
# Out:
# array([ 95.01724869,  69.12380733,   0.48968187,  47.05894682,
#          4.67473068,  40.67623396,  64.21756915,  80.53317201,
#         84.53778094,  76.21458325,  28.2380596 ,  54.32356712,
#         21.16504806,  52.59957334,  65.78326666,  54.08796086,
#         65.67253313,  51.64959973,   9.65024989,  26.83019698,
#         14.21042473,  13.33719378,  18.38719552,  13.45049344,
#         97.07057711,  18.73437919,  39.92258068,  12.73583334,
#         34.15880868,  27.34334446,  63.40891363,  36.87074717,
#         33.79820623,  21.86138707,  17.0335533 ,  38.27908563,
#          4.80311074,  36.92550198,  51.52779024,  97.34127621,
#         32.06991078,  64.89984571,  59.66134846,  48.30605468,
#          0.8439178 ,  37.71842933,  88.4417325 ,  72.57061663,
#         90.17827533,  21.40222012,  50.        ,  50.        ,
#         50.        ,  50.        ,  50.        ,  50.        ,
#         50.        ,  50.        ,  50.        ,  50.        ,
#         50.        ,  50.        ,  50.        ,  50.        ,
#         50.        ,  50.        ,  50.        ,  50.        ,
#         50.        ,  50.        ,  50.        ,  50.        ,
#         50.        ,  50.        ,  50.        , 152.12564387,
#        159.53092968, 128.24711871, 161.46335708, 119.74804423,
#        123.07403083, 187.28301266, 108.50690613, 171.37788628,
#        138.51984808, -90.21203423, -11.21848891, -58.83305068,
#        -20.42825891, -33.45777572, -81.12987221, -61.30977143,
#        -78.75615113, -89.19223415, -21.69129016])

# %%
data.shape
# Out:
# (95,)

# %%
#creando boxplot
fig1,ax1 = plt.subplots()
ax1.set_title('boxplot')
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x74b3c3209950>,
#   <matplotlib.lines.Line2D at 0x74b3c3209a90>],
#  'caps': [<matplotlib.lines.Line2D at 0x74b3c3209bd0>,
#   <matplotlib.lines.Line2D at 0x74b3c3209d10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x74b3c3209810>],
#  'medians': [<matplotlib.lines.Line2D at 0x74b3c3209e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x74b3c3209f90>],
#  'means': []}

# %%
#con notch
fig2,ax2 = plt.subplots()
ax2.set_title('boxplot')
ax2.boxplot(data, notch= True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x74b3c326d1d0>,
#   <matplotlib.lines.Line2D at 0x74b3c326d310>],
#  'caps': [<matplotlib.lines.Line2D at 0x74b3c326d450>,
#   <matplotlib.lines.Line2D at 0x74b3c326d590>],
#  'boxes': [<matplotlib.lines.Line2D at 0x74b3c326d090>],
#  'medians': [<matplotlib.lines.Line2D at 0x74b3c326d6d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x74b3c326d810>],
#  'means': []}

# %%
#cambiando color outliers
green_diamond = dict(markerfacecolor = "g", marker = "D")
fig3,ax3 = plt.subplots()
ax3.set_title('boxplot')
ax3.boxplot(data, notch= True, flierprops = green_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x74b3c32dca50>,
#   <matplotlib.lines.Line2D at 0x74b3c32dcb90>],
#  'caps': [<matplotlib.lines.Line2D at 0x74b3c32dccd0>,
#   <matplotlib.lines.Line2D at 0x74b3c32dce10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x74b3c32dc910>],
#  'medians': [<matplotlib.lines.Line2D at 0x74b3c3339950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x74b3c3339bd0>],
#  'means': []}

# %%
#sin outliers

fig3,ax3 = plt.subplots()
ax3.set_title('boxplot')
ax3.boxplot(data, notch= True, showfliers = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x74b3c3103b10>,
#   <matplotlib.lines.Line2D at 0x74b3c3103c50>],
#  'caps': [<matplotlib.lines.Line2D at 0x74b3c3103d90>,
#   <matplotlib.lines.Line2D at 0x74b3c3103ed0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x74b3c31039d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x74b3c311c050>],
#  'fliers': [],
#  'means': []}

# %%
# horizontal
#cambiando color outliers
red_square = dict(markerfacecolor = "r", marker = "s")
fig3,ax3 = plt.subplots()
ax3.set_title('boxplot')
ax3.boxplot(data, notch= True, flierprops = red_square, vert = False )
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x74b3c31582d0>,
#   <matplotlib.lines.Line2D at 0x74b3c3158410>],
#  'caps': [<matplotlib.lines.Line2D at 0x74b3c3158550>,
#   <matplotlib.lines.Line2D at 0x74b3c3158690>],
#  'boxes': [<matplotlib.lines.Line2D at 0x74b3c3158190>],
#  'medians': [<matplotlib.lines.Line2D at 0x74b3c31587d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x74b3c3158910>],
#  'means': []}

# %%
# modificando tamaño de bigotes, whis, por defecto 1.5 RIQ
red_square = dict(markerfacecolor = "r", marker = "s")
fig3,ax3 = plt.subplots()
ax3.set_title('boxplot')
ax3.boxplot(data, notch= True, flierprops = red_square, vert = False , whis = 1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x74b3c3187b10>,
#   <matplotlib.lines.Line2D at 0x74b3c3187c50>],
#  'caps': [<matplotlib.lines.Line2D at 0x74b3c3187d90>,
#   <matplotlib.lines.Line2D at 0x74b3c3187ed0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x74b3c31879d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x74b3c31cc050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x74b3c31cc190>],
#  'means': []}

# %%
# con multiples cajas
dist1 = 100 * np.random.rand(50)
dist2 = 100 * np.ones(25)
dist3 = 100 + 100*np.random.rand(10)
dist4 = -100 * np.random.rand(10)

data2 = np.concatenate((dist1,dist2,dist3,dist4))
data3 = data2[::2]

# %%
# apartir de aqui da error siguiendo el video, hay que hacerlo como se muestra mas adelante

# queremos que queden por columna, ya que actualmente los data son un renglon, para ello hacemos
data.shape = (-1,1)
#con lo cual pasan a ser de una sola columna, y ademas pasan a dos dimesiones
print(data.shape)

#igual para data 2 y 3
data2.shape = (-1,1)
# Out:
# (95, 1)

# %%
data3 = data2[::2,0] 
data3.shape
# Out:
# (48,)

# %%
fulldata = [data, data2 , data3 ]
fulldata
#tenemos una list con 3 arrays de dos dimensiones
# Out:
# [array([[ 95.01724869],
#         [ 69.12380733],
#         [  0.48968187],
#         [ 47.05894682],
#         [  4.67473068],
#         [ 40.67623396],
#         [ 64.21756915],
#         [ 80.53317201],
#         [ 84.53778094],
#         [ 76.21458325],
#         [ 28.2380596 ],
#         [ 54.32356712],
#         [ 21.16504806],
#         [ 52.59957334],
#         [ 65.78326666],
#         [ 54.08796086],
#         [ 65.67253313],
#         [ 51.64959973],
#         [  9.65024989],
#         [ 26.83019698],
#         [ 14.21042473],
#         [ 13.33719378],
#         [ 18.38719552],
#         [ 13.45049344],
#         [ 97.07057711],
#         [ 18.73437919],
#         [ 39.92258068],
#         [ 12.73583334],
#         [ 34.15880868],
#         [ 27.34334446],
#         [ 63.40891363],
#         [ 36.87074717],
#         [ 33.79820623],
#         [ 21.86138707],
#         [ 17.0335533 ],
#         [ 38.27908563],
#         [  4.80311074],
#         [ 36.92550198],
#         [ 51.52779024],
#         [ 97.34127621],
#         [ 32.06991078],
#         [ 64.89984571],
#         [ 59.66134846],
#         [ 48.30605468],
#         [  0.8439178 ],
#         [ 37.71842933],
#         [ 88.4417325 ],
#         [ 72.57061663],
#         [ 90.17827533],
#         [ 21.40222012],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [152.12564387],
#         [159.53092968],
#         [128.24711871],
#         [161.46335708],
#         [119.74804423],
#         [123.07403083],
#         [187.28301266],
#         [108.50690613],
#         [171.37788628],
#         [138.51984808],
#         [-90.21203423],
#         [-11.21848891],
#         [-58.83305068],
#         [-20.42825891],
#         [-33.45777572],
#         [-81.12987221],
#         [-61.30977143],
#         [-78.75615113],
#         [-89.19223415],
#         [-21.69129016]]),
#  array([[ 31.16973912],
#         [ 46.70100876],
#         [ 26.60993688],
#         [ 79.00773255],
#         [ 90.56672944],
#         [ 91.73344957],
#         [ 61.03538679],
#         [ 86.62796609],
#         [ 97.18490404],
#         [ 61.45512778],
#         [ 17.14542917],
#         [ 16.10378587],
#         [ 96.59853259],
#         [ 96.17832253],
#         [ 92.46883514],
#         [ 50.91704958],
#         [ 49.96398171],
#         [ 53.52049445],
#         [  4.0038454 ],
#         [ 31.62828316],
#         [ 31.87410909],
#         [ 48.333707  ],
#         [ 21.32083179],
#         [ 48.12846986],
#         [ 99.48323968],
#         [ 24.95000794],
#         [ 65.11671844],
#         [  1.3590582 ],
#         [  8.43531747],
#         [ 48.38046798],
#         [ 37.24106542],
#         [ 81.74682661],
#         [ 75.66841362],
#         [ 39.00937993],
#         [ 93.52469242],
#         [ 65.61157033],
#         [ 15.01880994],
#         [ 42.09380234],
#         [ 40.19375558],
#         [ 45.89231952],
#         [ 69.12420345],
#         [ 71.55040482],
#         [ 65.3823683 ],
#         [ 14.53332426],
#         [  6.94667025],
#         [ 84.56070612],
#         [  9.32278803],
#         [ 55.62053867],
#         [ 34.86982473],
#         [ 60.30033786],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [100.        ],
#         [103.49593088],
#         [105.87942329],
#         [127.31998555],
#         [107.49013385],
#         [196.46197876],
#         [102.14149696],
#         [168.23704473],
#         [150.40758612],
#         [160.05348904],
#         [133.78400788],
#         [-53.06158121],
#         [-54.87542598],
#         [-53.45636736],
#         [-18.05516401],
#         [ -3.8160298 ],
#         [-60.26200247],
#         [ -3.48314714],
#         [-36.83193855],
#         [-45.78419459],
#         [-75.2947361 ]]),
#  array([ 31.16973912,  26.60993688,  90.56672944,  61.03538679,
#          97.18490404,  17.14542917,  96.59853259,  92.46883514,
#          49.96398171,   4.0038454 ,  31.87410909,  21.32083179,
#          99.48323968,  65.11671844,   8.43531747,  37.24106542,
#          75.66841362,  93.52469242,  15.01880994,  40.19375558,
#          69.12420345,  65.3823683 ,   6.94667025,   9.32278803,
#          34.86982473, 100.        , 100.        , 100.        ,
#         100.        , 100.        , 100.        , 100.        ,
#         100.        , 100.        , 100.        , 100.        ,
#         100.        , 100.        , 105.87942329, 107.49013385,
#         102.14149696, 150.40758612, 133.78400788, -54.87542598,
#         -18.05516401, -60.26200247, -36.83193855, -75.2947361 ])]

# %%
fig_4, ax_4 = plt.subplots()
ax_4.set_title = ("multiples")
ax_4.boxplot(fulldata)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 3
#       1 fig_4, ax_4 = plt.subplots()
#       2 ax_4.set_title = ("multiples")
# ----> 3 ax_4.boxplot(fulldata)
#       4 plt.show()
#
# File ~/anaconda3/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.13/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:295, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     290     warn_deprecated(
#     291         since, message=f"The {old!r} parameter of {func.__name__}() "
#     292         f"has been renamed {new!r} since Matplotlib {since}; support "
#     293         f"for the old name will be dropped in %(removal)s.")
#     294     kwargs[new] = kwargs.pop(old)
# --> 295 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_axes.py:4110, in Axes.boxplot(self, x, notch, sym, vert, orientation, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label)
#    4107 if bootstrap is None:
#    4108     bootstrap = mpl.rcParams['boxplot.bootstrap']
# -> 4110 bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    4111                                labels=tick_labels, autorange=autorange)
#    4112 if notch is None:
#    4113     notch = mpl.rcParams['boxplot.notch']
#
# File ~/anaconda3/lib/python3.13/site-packages/matplotlib/cbook.py:1201, in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1198 bxpstats = []
#    1200 # convert X to a list of lists
# -> 1201 X = _reshape_2D(X, "X")
#    1203 ncols = len(X)
#    1204 if labels is None:
#
# File ~/anaconda3/lib/python3.13/site-packages/matplotlib/cbook.py:1412, in _reshape_2D(X, name)
#    1410     nd = np.ndim(xi)
#    1411     if nd > 1:
# -> 1412         raise ValueError(f'{name} must have 2 or fewer dimensions')
#    1413     result.append(xi.reshape(-1))
#    1415 if is_1d:
#    1416     # 1D array of scalars: directly return it.
#
# ValueError: X must have 2 or fewer dimensions

# %%
# al parecer ahora maximo debe ser X de dos dimensiones
data = data.flatten()
data2 = data2.flatten()
data3 = data3.flatten()

fulldata = [data,data2,data3]

fulldata
# Out:
# [array([ 95.01724869,  69.12380733,   0.48968187,  47.05894682,
#           4.67473068,  40.67623396,  64.21756915,  80.53317201,
#          84.53778094,  76.21458325,  28.2380596 ,  54.32356712,
#          21.16504806,  52.59957334,  65.78326666,  54.08796086,
#          65.67253313,  51.64959973,   9.65024989,  26.83019698,
#          14.21042473,  13.33719378,  18.38719552,  13.45049344,
#          97.07057711,  18.73437919,  39.92258068,  12.73583334,
#          34.15880868,  27.34334446,  63.40891363,  36.87074717,
#          33.79820623,  21.86138707,  17.0335533 ,  38.27908563,
#           4.80311074,  36.92550198,  51.52779024,  97.34127621,
#          32.06991078,  64.89984571,  59.66134846,  48.30605468,
#           0.8439178 ,  37.71842933,  88.4417325 ,  72.57061663,
#          90.17827533,  21.40222012,  50.        ,  50.        ,
#          50.        ,  50.        ,  50.        ,  50.        ,
#          50.        ,  50.        ,  50.        ,  50.        ,
#          50.        ,  50.        ,  50.        ,  50.        ,
#          50.        ,  50.        ,  50.        ,  50.        ,
#          50.        ,  50.        ,  50.        ,  50.        ,
#          50.        ,  50.        ,  50.        , 152.12564387,
#         159.53092968, 128.24711871, 161.46335708, 119.74804423,
#         123.07403083, 187.28301266, 108.50690613, 171.37788628,
#         138.51984808, -90.21203423, -11.21848891, -58.83305068,
#         -20.42825891, -33.45777572, -81.12987221, -61.30977143,
#         -78.75615113, -89.19223415, -21.69129016]),
#  array([ 31.16973912,  46.70100876,  26.60993688,  79.00773255,
#          90.56672944,  91.73344957,  61.03538679,  86.62796609,
#          97.18490404,  61.45512778,  17.14542917,  16.10378587,
#          96.59853259,  96.17832253,  92.46883514,  50.91704958,
#          49.96398171,  53.52049445,   4.0038454 ,  31.62828316,
#          31.87410909,  48.333707  ,  21.32083179,  48.12846986,
#          99.48323968,  24.95000794,  65.11671844,   1.3590582 ,
#           8.43531747,  48.38046798,  37.24106542,  81.74682661,
#          75.66841362,  39.00937993,  93.52469242,  65.61157033,
#          15.01880994,  42.09380234,  40.19375558,  45.89231952,
#          69.12420345,  71.55040482,  65.3823683 ,  14.53332426,
#           6.94667025,  84.56070612,   9.32278803,  55.62053867,
#          34.86982473,  60.30033786, 100.        , 100.        ,
#         100.        , 100.        , 100.        , 100.        ,
#         100.        , 100.        , 100.        , 100.        ,
#         100.        , 100.        , 100.        , 100.        ,
#         100.        , 100.        , 100.        , 100.        ,
#         100.        , 100.        , 100.        , 100.        ,
#         100.        , 100.        , 100.        , 103.49593088,
#         105.87942329, 127.31998555, 107.49013385, 196.46197876,
#         102.14149696, 168.23704473, 150.40758612, 160.05348904,
#         133.78400788, -53.06158121, -54.87542598, -53.45636736,
#         -18.05516401,  -3.8160298 , -60.26200247,  -3.48314714,
#         -36.83193855, -45.78419459, -75.2947361 ]),
#  array([ 31.16973912,  26.60993688,  90.56672944,  61.03538679,
#          97.18490404,  17.14542917,  96.59853259,  92.46883514,
#          49.96398171,   4.0038454 ,  31.87410909,  21.32083179,
#          99.48323968,  65.11671844,   8.43531747,  37.24106542,
#          75.66841362,  93.52469242,  15.01880994,  40.19375558,
#          69.12420345,  65.3823683 ,   6.94667025,   9.32278803,
#          34.86982473, 100.        , 100.        , 100.        ,
#         100.        , 100.        , 100.        , 100.        ,
#         100.        , 100.        , 100.        , 100.        ,
#         100.        , 100.        , 105.87942329, 107.49013385,
#         102.14149696, 150.40758612, 133.78400788, -54.87542598,
#         -18.05516401, -60.26200247, -36.83193855, -75.2947361 ])]

# %%
fig_4, ax_4 = plt.subplots()
ax_4.set_title = ("multiples")
ax_4.boxplot(fulldata)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x74b3c30eb4d0>,
#   <matplotlib.lines.Line2D at 0x74b3c30eb610>,
#   <matplotlib.lines.Line2D at 0x74b3c30ebd90>,
#   <matplotlib.lines.Line2D at 0x74b3c30ebed0>,
#   <matplotlib.lines.Line2D at 0x74b3c2f08690>,
#   <matplotlib.lines.Line2D at 0x74b3c2f087d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x74b3c30eb750>,
#   <matplotlib.lines.Line2D at 0x74b3c30eb890>,
#   <matplotlib.lines.Line2D at 0x74b3c2f08050>,
#   <matplotlib.lines.Line2D at 0x74b3c2f08190>,
#   <matplotlib.lines.Line2D at 0x74b3c2f08910>,
#   <matplotlib.lines.Line2D at 0x74b3c2f08a50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x74b3c30eb390>,
#   <matplotlib.lines.Line2D at 0x74b3c30ebc50>,
#   <matplotlib.lines.Line2D at 0x74b3c2f08550>],
#  'medians': [<matplotlib.lines.Line2D at 0x74b3c30eb9d0>,
#   <matplotlib.lines.Line2D at 0x74b3c2f082d0>,
#   <matplotlib.lines.Line2D at 0x74b3c2f08b90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x74b3c30ebb10>,
#   <matplotlib.lines.Line2D at 0x74b3c2f08410>,
#   <matplotlib.lines.Line2D at 0x74b3c2f08cd0>],
#  'means': []}
