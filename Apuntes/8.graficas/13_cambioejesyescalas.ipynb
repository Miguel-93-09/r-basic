# %%
# %matplotlib inline 
import numpy as np
import matplotlib.pyplot as plt

# %%
mu = 0.5
sigma= 0.3
y = mu + sigma * np.random.randn(1000)
y = y[(y>0) & (y<1)]
y.sort()
x = np.arange(len(y))

# %%
plt.figure(1)

plt.subplot(2,2,1)
plt.plot(x,y)
#normal las escalas son lineales
plt.yscale("linear")
plt.xscale("linear")
plt.title("escala lineal")
plt.grid(True)

plt.subplot(2,2,2)
plt.plot(x,y)
plt.yscale("log")
plt.xscale("linear")
plt.title("escala log en y")
plt.grid(True)

#eje logaritmico simetrico, con media de datos en 0

plt.subplot(2,2,3)
plt.plot(x, y-y.mean())
plt.yscale('symlog') 
plt.title("escala log simetrico")
plt.grid(True)


plt.subplot(2,2,4)
plt.plot(x, y)
plt.yscale('logit') 
plt.title("escala logistica")
plt.grid(True)

plt.show()

# %%
# arregalar vistas, permite anular divisiones de uno de los ejes cuando aparecen muchos numeritos
from matplotlib.ticker import NullFormatter

# %%
#arregando sobreescritura
plt.figure(1)

plt.subplot(2,2,1)
plt.plot(x,y)
#normal las escalas son lineales
plt.yscale("linear")
plt.xscale("linear")
plt.title("escala lineal")
plt.grid(True)

plt.subplot(2,2,2)
plt.plot(x,y)
plt.yscale("log")
plt.xscale("linear")
plt.title("escala log en y")
plt.grid(True)

#eje logaritmico simetrico, con media de datos en 0

plt.subplot(2,2,3)
plt.plot(x, y-y.mean())
plt.yscale('symlog') 
plt.title("escala log simetrico")
plt.grid(True)


plt.subplot(2,2,4)
plt.plot(x, y)
plt.yscale('logit') 
plt.title("escala logistica")
plt.grid(True)

plt.subplots_adjust(top=0.92, bottom=0.08, left=0.1, right=0.95, hspace=0.25, wspace=0.35)

plt.show()

# %%
#arregando sobreescritura, sencillo
plt.figure(1, figsize=(10,8))

plt.subplot(2,2,1)
plt.plot(x,y)
#normal las escalas son lineales
plt.yscale("linear")
plt.xscale("linear")
plt.title("escala lineal")
plt.grid(True)

plt.subplot(2,2,2)
plt.plot(x,y)
plt.yscale("log")
plt.xscale("linear")
plt.title("escala log en y")
plt.grid(True)

#eje logaritmico simetrico, log hacia arriba y hacia abajo, con media de datos en 0, admite eje negativo

plt.subplot(2,2,3)
plt.plot(x, y-y.mean())
plt.yscale('symlog') 
plt.title("escala log simetrico")
plt.grid(True)


plt.subplot(2,2,4)
plt.plot(x, y)
plt.yscale('logit') 
plt.title("escala logistica")
plt.grid(True)

plt.subplots_adjust(hspace=0.2, wspace=0.2)

plt.show()
