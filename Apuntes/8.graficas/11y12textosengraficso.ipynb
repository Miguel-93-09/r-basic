# %% [markdown]
# # figura
# es como un cuadrado, una ventana donde se habilita la posibildiad de hacer una represetacion grafica
#
# # ejes
# dentro de la figura va otro cuadrado, donde van los ejes , a la vez los plots estan contenidos en dicho eje.
#
# cuando se activa hold, esto significa  que cada grafico sobreescribe el anterior, no se sobrepone.
#
# # multiples grafos multilples subplots no sobrreescritos
# se trabaja con los subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
mu = 100
sigma = 20

x = mu + sigma * np.random.randn(10000)

# %%
x
# Out:
# array([114.2702144 ,  86.31108909,  98.55799036, ..., 100.40134734,
#        111.43234213, 104.35932959])

# %%
n, bins, patches = plt.hist(x, 50, density=1 , facecolor = "g", alpha = 0.8)
plt.xlabel(r"peso $N$")
plt.ylabel("proba")

#modificando detalles titulos, tectos
plt.title("histo 1", fontsize = 14, color = "g")

#añadiendo texto en grafico, para latex usar : r"text $latex$ "
plt.text(40,0.015, r'$\mu = 100,\ \sigma=20$' )

plt.axis([20,180,0,0.025])

#añade grid
plt.grid(True)


plt.show()
# Out:
# <BarContainer object of 50 artists>

# %%
# flecha con texto, y fig con otros detalles, el size esta en pulgadas
plt.figure(1,figsize=(10,6),dpi=90)
#solo un grafico
plt.subplot(111)
x = np.arange(0,2*np.pi,0.01)
y=np.cos(x)
plt.plot(x,y, lw=2)

#apuntemos a el valor minimo en pi, putna de la flecha se especifica en xy, el texto en xytext
#shrink es largo flecha

plt.annotate('Mínimo local', 
             xy = (np.pi,-1),
             xytext = (np.pi,-0.5),
             arrowprops = dict(facecolor = "black", shrink = 1 ))

plt.ylim(-2.2)

plt.show()

# %%
help(plt.annotate)
# Out:
# Help on function annotate in module matplotlib.pyplot:
#
# annotate(text: 'str', xy: 'tuple[float, float]', xytext: 'tuple[float, float] | None' = None, xycoords: 'CoordsType' = 'data', textcoords: 'CoordsType | None' = None, arrowprops: 'dict[str, Any] | None' = None, annotation_clip: 'bool | None' = None, **kwargs) -> 'Annotation'
#     Annotate the point *xy* with text *text*.
#
#     In the simplest form, the text is placed at *xy*.
#
#     Optionally, the text can be displayed in another position *xytext*.
#     An arrow pointing from the text to the annotated point *xy* can then
#     be added by defining *arrowprops*.
#
#     Parameters
#     ----------
#     text : str
#         The text of the annotation.
#
#     xy : (float, float)
#         The point *(x, y)* to annotate. The coordinate system is determined
#         by *xycoords*.
#
#     xytext : (float, float), default: *xy*
#         The position *(x, y)* to place the text at. The coordinate system
# ...
